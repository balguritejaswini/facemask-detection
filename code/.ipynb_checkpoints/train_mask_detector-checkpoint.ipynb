# %%
# import the necessary packages
import os
import argparse
import numpy as np
from imutils import paths
import matplotlib.pyplot as plt
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
# set the paths on where the dataset is, where to save the model and plot
dataset_path = "/Users/Tejaswini/Documents/CV/Facemask Detection/dataset"
model_path = "/Users/Tejaswini/Documents/CV/Facemask Detection/model"
plot_path = "/Users/Tejaswini/Documents/CV/Facemask Detection/plot"

# %%
# initialize the initial learning rate, number of epochs to train for,
# and batch size
INIT_LEARNING_RATE = 1e-4
EPOCHS = 20
BATCH_SIZE = 32

# %%
# fetch the images from the dataset directory, then initialize
# the list of data (i.e., images) and class images
print("Loading images...")
imagePaths = list(paths.list_images(dataset_path))
data = []
labels = []
# Out:
# Loading images...

# %%
# loop over the image paths
for imagePath in imagePaths:
	# extract the class label from the filename
	label = imagePath.split(os.path.sep)[-2]
	print(imagePath)

	# load the input image (224x224) and preprocess it
	image = load_img(imagePath, target_size=(224, 224))
	image = img_to_array(image)
	image = preprocess_input(image)

	# update the data and labels lists, respectively
	data.append(image)
	labels.append(label)
# Out:
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_218.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_19.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_31.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_25.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_230.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/419-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/330-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/260-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/27-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/327-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/277-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/30-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_3.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_152.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_146.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/309-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/259-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/420-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_191.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/155-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_185.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/89-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/273-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/323-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/34-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_184.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/334-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/23-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_190.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/168-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_147.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/prajna.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_153.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_2.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/433-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/146-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/424-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/151-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_24.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_30.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_18.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_219.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_26.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_32.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_227.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/40-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/207-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/357-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/57-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/340-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_179.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_145.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/8-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_0.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_151.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/79-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/283-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_186.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/132-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_192.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/447-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/294-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/125-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/450-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/229-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/379-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/198-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/118-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/53-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/344-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/214-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_193.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/353-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/203-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_187.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_150.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_1.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_144.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_178.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/290-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/121-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/454-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/287-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/136-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/443-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_33.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_232.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_27.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_23.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_236.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_222.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_37.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/343-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/204-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/43-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/108-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_140.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_5.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_154.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_168.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_183.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_197.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/297-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/453-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/126-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/444-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/131-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/479-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/200-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/47-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/347-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/217-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/50-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_196.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_182.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_169.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_155.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_4.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_141.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/369-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/239-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/284-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/440-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/135-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/293-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/457-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/122-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_223.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_36.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_22.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_237.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_34.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_221.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_235.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_20.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_209.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/399-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/33-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/324-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/274-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/24-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/333-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/263-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/99-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_6.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_157.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_143.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_194.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_180.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/141-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/434-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/156-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/267-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/37-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/270-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/409-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_181.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_195.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_142.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_156.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_7.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/19-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/152-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/427-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/430-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/319-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_208.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_234.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_21.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_35.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_220.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_52.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_247.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_46.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/397-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/80-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/176-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_91.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_284.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_85.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/380-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/97-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/414-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/161-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_119.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_131.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_125.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/313-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/243-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/158-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/304-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/254-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/13-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/pra1.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/384-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/93-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/165-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/269-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/339-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/39-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/393-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/84-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/407-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/172-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_124.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_130.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_118.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/17-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/429-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_291.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_84.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_90.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_285.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/317-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_252.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_47.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_53.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_246.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_79.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_45.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_244.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_51.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/111-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/464-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_86.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_287.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_92.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/106-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/473-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_126.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/augmented_image_132.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/195-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask/224-with-mask.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/with_mask
jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/468.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/454.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/332.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/326.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/440.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/118.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_88.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/130.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/124.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/31.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_63.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_276.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/19.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_262.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_77.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_239.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/42.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/4.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_38.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/56.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_205.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/180.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/194.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_211.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/81.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/95.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/143.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/157.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/341.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/427.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/355.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_173.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_198.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/221.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/220.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/234.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_199.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/208.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_166.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_172.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/432.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/354.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/340.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/426.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/368.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/397.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/383.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/156.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/142.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/94.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/80.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/195.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_210.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_204.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/181.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_39.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/57.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/43.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_238.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/55.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/7.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/69.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/197.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/183.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_13.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_206.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/96.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/168.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/154.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/140.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/395.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/356.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/430.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/424.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_158.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_164.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_170.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/222.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/237.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/223.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_171.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_165.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/425.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/431.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/419.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/394.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/141.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/155.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/83.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/97.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/169.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_12.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_207.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/196.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/40.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/54.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/6.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/192.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_203.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/186.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_16.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/2.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/50.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/44.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/151.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/145.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/93.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/87.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/179.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/390.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/384.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/435.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/353.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/347.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/421.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/409.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_161.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_175.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_149.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/227.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/233.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/232.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/226.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_148.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_174.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_160.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/408.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/420.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/434.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/352.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/385.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/391.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/86.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/178.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/92.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/45.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/3.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/51.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_202.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/79.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_17.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/187.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/193.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_216.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/185.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_200.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_214.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/191.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/47.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/53.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/1.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/146.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/152.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/84.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/90.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/387.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/393.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/422.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/344.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/350.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/436.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/378.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_176.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_162.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/230.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/224.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_189.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/218.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_188.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/225.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/231.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_163.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_177.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/379.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/351.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/437.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/423.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/345.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/392.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/386.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/91.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/153.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_229.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/52.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/0.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/46.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_215.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/184.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_14.jpg
# /Users/vineelgannu/Desktop/Facemask Detection/dataset/without_mask/augmented_image_201.jpg

# %%
# convert the data and labels to NumPy arrays
data = np.array(data, dtype="float32")
labels = np.array(labels)

# %% [markdown]
# # New section

# %%
# perform one-hot encoding on the labels
label_binarizer = LabelBinarizer()
labels = label_binarizer.fit_transform(labels)
labels = to_categorical(labels)

# %%
# partition the data into training and testing splits using 80% of
# the data for training and 20% for testing
(trainX, testX, trainY, testY) = train_test_split(data, labels,
	test_size=0.20, stratify=labels, random_state=42)

# %%
# construct the training image generator for data augmentation
aug = ImageDataGenerator(
	rotation_range=20,
	zoom_range=0.15,
	width_shift_range=0.2,
	height_shift_range=0.2,
	shear_range=0.15,
	horizontal_flip=True,
	fill_mode="nearest")

# %%
# load the MobileNetV2 network, ensuring the head FC layer sets are
# left off
baseModel = MobileNetV2(weights="imagenet", include_top=False,
	input_tensor=Input(shape=(224, 224, 3)))
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# 2022-08-14 12:34:13.408070: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# construct the head of the model that will be placed on top of the
# the base model
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(7, 7))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(2, activation="softmax")(headModel)

# %%
# place the head FC model on top of the base model (this will become
# the actual model we will train)
model = Model(inputs=baseModel.input, outputs=headModel)

# %%
# loop over all layers in the base model and freeze them so they will
# *not* be updated during the first training process
for layer in baseModel.layers:
	layer.trainable = False

# %%
# compile our model
print("Compiling model...")
opt = Adam(lr=INIT_LEARNING_RATE, decay=INIT_LEARNING_RATE / EPOCHS)
model.compile(loss="binary_crossentropy", optimizer=opt,
	metrics=["accuracy"])
# Out:
# Compiling model...
# /usr/local/anaconda3/lib/python3.9/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# train the head of the network
print("Training head...")
H = model.fit(
	aug.flow(trainX, trainY, batch_size=BATCH_SIZE),
	steps_per_epoch=len(trainX) // BATCH_SIZE,
	validation_data=(testX, testY),
	validation_steps=len(testX) // BATCH_SIZE,
	epochs=EPOCHS)
# Out:
# Training head...
# Epoch 1/20
# 34/34 [==============================] - 25s 692ms/step - loss: 0.5534 - accuracy: 0.7697 - val_loss: 0.2486 - val_accuracy: 0.9855
# Epoch 2/20
# 34/34 [==============================] - 26s 755ms/step - loss: 0.2274 - accuracy: 0.9672 - val_loss: 0.1104 - val_accuracy: 0.9964
# Epoch 3/20
# 34/34 [==============================] - 27s 781ms/step - loss: 0.1305 - accuracy: 0.9719 - val_loss: 0.0659 - val_accuracy: 0.9964
# Epoch 4/20
# 34/34 [==============================] - 27s 798ms/step - loss: 0.0935 - accuracy: 0.9906 - val_loss: 0.0467 - val_accuracy: 0.9964
# Epoch 5/20
# 34/34 [==============================] - 31s 901ms/step - loss: 0.0624 - accuracy: 0.9916 - val_loss: 0.0349 - val_accuracy: 0.9964
# Epoch 6/20
# 34/34 [==============================] - 28s 822ms/step - loss: 0.0528 - accuracy: 0.9906 - val_loss: 0.0290 - val_accuracy: 0.9964
# Epoch 7/20
# 34/34 [==============================] - 35s 1s/step - loss: 0.0481 - accuracy: 0.9888 - val_loss: 0.0277 - val_accuracy: 0.9928
# Epoch 8/20
# 34/34 [==============================] - 50s 1s/step - loss: 0.0405 - accuracy: 0.9925 - val_loss: 0.0213 - val_accuracy: 0.9964
# Epoch 9/20
# 34/34 [==============================] - 43s 1s/step - loss: 0.0327 - accuracy: 0.9963 - val_loss: 0.0201 - val_accuracy: 0.9964
# Epoch 10/20
# 34/34 [==============================] - 39s 1s/step - loss: 0.0362 - accuracy: 0.9944 - val_loss: 0.0192 - val_accuracy: 0.9964
# Epoch 11/20
# 34/34 [==============================] - 40s 1s/step - loss: 0.0295 - accuracy: 0.9934 - val_loss: 0.0210 - val_accuracy: 0.9928
# Epoch 12/20
# 34/34 [==============================] - 35s 1s/step - loss: 0.0269 - accuracy: 0.9906 - val_loss: 0.0175 - val_accuracy: 0.9964
# Epoch 13/20
# 34/34 [==============================] - 31s 919ms/step - loss: 0.0302 - accuracy: 0.9925 - val_loss: 0.0182 - val_accuracy: 0.9964
# Epoch 14/20
# 34/34 [==============================] - 37s 1s/step - loss: 0.0297 - accuracy: 0.9916 - val_loss: 0.0156 - val_accuracy: 0.9964
# Epoch 15/20
# 34/34 [==============================] - 46s 1s/step - loss: 0.0196 - accuracy: 0.9991 - val_loss: 0.0145 - val_accuracy: 0.9964
# Epoch 16/20
# 34/34 [==============================] - 78s 2s/step - loss: 0.0192 - accuracy: 0.9963 - val_loss: 0.0165 - val_accuracy: 0.9928
# Epoch 17/20
# 34/34 [==============================] - 45s 1s/step - loss: 0.0183 - accuracy: 0.9963 - val_loss: 0.0112 - val_accuracy: 0.9964
# Epoch 18/20
# 34/34 [==============================] - 57s 2s/step - loss: 0.0174 - accuracy: 0.9963 - val_loss: 0.0139 - val_accuracy: 0.9928
# Epoch 19/20
# 34/34 [==============================] - 55s 2s/step - loss: 0.0151 - accuracy: 0.9991 - val_loss: 0.0153 - val_accuracy: 0.9928
# Epoch 20/20
# 34/34 [==============================] - 37s 1s/step - loss: 0.0162 - accuracy: 0.9972 - val_loss: 0.0125 - val_accuracy: 0.9964

# %%
# make predictions on the testing set
print("Evaluating network...")
predIdxs = model.predict(testX, batch_size=BATCH_SIZE)
# Out:
# Evaluating network...
# 9/9 [==============================] - 7s 670ms/step

# %%
# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
predIdxs = np.argmax(predIdxs, axis=1)

# %%
# show a classification report
print(classification_report(testY.argmax(axis=1), predIdxs,
    target_names=label_binarizer.classes_))
# Out:
#               precision    recall  f1-score   support
#
#    with_mask       0.99      1.00      1.00       138
# without_mask       1.00      0.99      1.00       138
#
#     accuracy                           1.00       276
#    macro avg       1.00      1.00      1.00       276
# weighted avg       1.00      1.00      1.00       276

# %%
# serialize the model to disk
print("Saving mask detector model...")
model.save(model_path, save_format="h5")
# Out:
# Saving mask detector model...

# %%
# plot the training loss and accuracy
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig(plot_path)
